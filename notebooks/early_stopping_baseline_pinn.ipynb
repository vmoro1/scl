# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
# path for loading
path = '/Users/vigoro/SCL_cleaned_code/scl/saved/convection/2025-02-07 11:17:48_baseline_pinn_convection'

# %%
# load loss and reativer error
loss = np.load(path + '/loss.npy')
relative_error = np.load(path + '/relative_error.npy')

eval_every = 1
epochs = 200000

# %%
# min loss
min_loss = np.min(loss)
min_loss_index = np.argmin(loss)
print(f"Minimum loss: {min_loss} at epoch index: {min_loss_index}")
# Out:
# Minimum loss: 0.0001587751612532884 at epoch index: 199664

# %%
# # min error
# min_relative_error = np.min(relative_error)
# min_relative_error_index = np.argmin(relative_error)
# print(f"Minimum relative error: {min_relative_error} at epoch index: {min_relative_error_index}")

# %%
# error for min loss
idx_error = int(min_loss_index / eval_every)
print(f"Relative error for lowest loss: {relative_error[idx_error]}")
# Out:
# Relative error for lowest loss: 0.008729407040390842

# %%
# sanity check
plt.figure()
plt.plot(np.arange(1,epochs + 1), loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.Figure()
plt.plot(np.arange(0, epochs, eval_every) + 1 , relative_error)
plt.xlabel('Epochs')
plt.ylabel('Relative error')
# Out:
# Text(0, 0.5, 'Relative error')
